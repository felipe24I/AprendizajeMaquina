# %% [markdown]
# <a href="https://colab.research.google.com/github/felipe24I/AprendizajeMaquina/blob/main/Taller_1/5_DL_Keras_API_funcional.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Ejercicio:
# - Grafique el espacio proyectado de PCA en 2D (etiquetas e imágenes) para los atributos aprendidos por la capa de concatenación.
#
# - Repita el proceso aplicando la técnica de reducción de dimensión UMAP de RAPIDS.
#
# - Plantee una nueva arquitectura tipo funcional utilizando capas convolucionales (Ver cuaderno CNNs) para el entrenamiento de la base de datos Mnist-digitos, utilizando tres entradas: i) imágenes limpias, ii) y iii) imágenes con ruido blanco Gaussiano ante diferentes varianzas, y dos salidas i) estimación del digito, ii) estimación número par número impar.

# %% [markdown]
# ###Punto 1:

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

train, test = tf.keras.datasets.fashion_mnist.load_data()
images, labels = train

# plt.imshow(images[10000,:,:], cmap = 'binary')
# plt.show()
# print(np.unique(labels))

# Normalización de los valores de los pixeles
images = images / 255.
x, y = test
x = x / 255.

#arquitectura funcional
tf.keras.backend.clear_session()

input_l = tf.keras.layers.Input(shape = (images.shape[1], images.shape[2]), name = 'Input')
flatten = tf.keras.layers.Flatten(input_shape = (images.shape[1], images.shape[2]))(input_l)
h1 = tf.keras.layers.Dense(200, activation = 'tanh', name = 'h1')(flatten)
h2 = tf.keras.layers.Dense(50, activation = 'tanh', name = 'h2')(h1)
concatenate = tf.keras.layers.concatenate([h2, flatten])
output_lA = tf.keras.layers.Dense(10, activation = "softmax", name = 'OutputA')(h2)
output_lB = tf.keras.layers.Dense(10, activation = "softmax", name = 'OutputB')(concatenate)

model = tf.keras.Model(inputs = input_l, outputs = [output_lA, output_lB])
# model.summary()
# tf.keras.utils.plot_model(model)
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = "Adam",
              metrics = ["accuracy","accuracy"])

history = model.fit(images, [labels, labels] , epochs = 10, batch_size = 64,
                        validation_split = 0.2)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - OutputA_accuracy: 0.7606 - OutputA_loss: 0.6867 - OutputB_accuracy: 0.7355 - OutputB_loss: 0.7887 - loss: 1.4754 - val_OutputA_accuracy: 0.8509 - val_OutputA_loss: 0.4138 - val_OutputB_accuracy: 0.8487 - val_OutputB_loss: 0.4190 - val_loss: 0.8329
# Epoch 2/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - OutputA_accuracy: 0.8618 - OutputA_loss: 0.3851 - OutputB_accuracy: 0.8597 - OutputB_loss: 0.3940 - loss: 0.7791 - val_OutputA_accuracy: 0.8658 - val_OutputA_loss: 0.3680 - val_OutputB_accuracy: 0.8621 - val_OutputB_loss: 0.3787 - val_loss: 0.7472
# Epoch 3/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - OutputA_accuracy: 0.8759 - OutputA_loss: 0.3477 - OutputB_accuracy: 0.8730 - OutputB_loss: 0.3559 - loss: 0.7035 - val_OutputA_accuracy: 0.8716 - val_OutputA_loss: 0.3493 - val_OutputB_accuracy: 0.8720 - val_OutputB_loss: 0.3537 - val_loss: 0.7035
# Epoch 4/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - OutputA_accuracy: 0.8815 - OutputA_loss: 0.3250 - OutputB_accuracy: 0.8797 - OutputB_loss: 0.3321 - loss: 0.6571 - val_OutputA_accuracy: 0.8777 - val_OutputA_loss: 0.3382 - val_OutputB_accuracy: 0.8737 - val_OutputB_loss: 0.3475 - val_loss: 0.6859
# Epoch 5/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - OutputA_accuracy: 0.8917 - OutputA_loss: 0.2978 - OutputB_accuracy: 0.8890 - OutputB_loss: 0.3042 - loss: 0.6020 - val_OutputA_accuracy: 0.8767 - val_OutputA_loss: 0.3336 - val_OutputB_accuracy: 0.8739 - val_OutputB_loss: 0.3409 - val_loss: 0.6751
# Epoch 6/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - OutputA_accuracy: 0.8958 - OutputA_loss: 0.2804 - OutputB_accuracy: 0.8935 - OutputB_loss: 0.2843 - loss: 0.5647 - val_OutputA_accuracy: 0.8803 - val_OutputA_loss: 0.3291 - val_OutputB_accuracy: 0.8748 - val_OutputB_loss: 0.3404 - val_loss: 0.6701
# Epoch 7/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - OutputA_accuracy: 0.9020 - OutputA_loss: 0.2679 - OutputB_accuracy: 0.8996 - OutputB_loss: 0.2742 - loss: 0.5421 - val_OutputA_accuracy: 0.8845 - val_OutputA_loss: 0.3121 - val_OutputB_accuracy: 0.8845 - val_OutputB_loss: 0.3127 - val_loss: 0.6253
# Epoch 8/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - OutputA_accuracy: 0.9026 - OutputA_loss: 0.2587 - OutputB_accuracy: 0.9029 - OutputB_loss: 0.2618 - loss: 0.5205 - val_OutputA_accuracy: 0.8880 - val_OutputA_loss: 0.3106 - val_OutputB_accuracy: 0.8823 - val_OutputB_loss: 0.3282 - val_loss: 0.6390
# Epoch 9/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - OutputA_accuracy: 0.9090 - OutputA_loss: 0.2467 - OutputB_accuracy: 0.9054 - OutputB_loss: 0.2513 - loss: 0.4980 - val_OutputA_accuracy: 0.8801 - val_OutputA_loss: 0.3279 - val_OutputB_accuracy: 0.8785 - val_OutputB_loss: 0.3423 - val_loss: 0.6706
# Epoch 10/10
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - OutputA_accuracy: 0.9109 - OutputA_loss: 0.2356 - OutputB_accuracy: 0.9105 - OutputB_loss: 0.2396 - loss: 0.4752 - val_OutputA_accuracy: 0.8789 - val_OutputA_loss: 0.3251 - val_OutputB_accuracy: 0.8761 - val_OutputB_loss: 0.3330 - val_loss: 0.6582

# %%
model_A = tf.keras.Model(inputs = model.inputs, outputs = model.get_layer('concatenate').output)
z_A = model_A.predict(x)
# z_A.shape
from sklearn.decomposition import PCA
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

#plot mnist 2D
def plot_mnist_2d(Z, y, images, img_w = 28, img_h = 28, zoom = 0.5, cmap = 'jet'):
    fig, ax = plt.subplots(figsize = (16,10))
    for i in range(Z.shape[0]):
        image = images[i].reshape((img_w, img_h))
        im = OffsetImage(image, zoom=zoom,cmap=cmap)
        ab = AnnotationBbox(im, (Z[i,0], Z[i,1]), xycoords='data', frameon=False)
        ax.add_artist(ab)
        ax.update_datalim([(Z[i,0], Z[i,1])])
        ax.autoscale()

zPCA = PCA(n_components=2).fit_transform(z_A)

plt.scatter(zPCA[:,0], zPCA[:,1], c = y)
plt.colorbar()
plt.xlabel('componente 1')
plt.ylabel('componente 2')
plt.title('PCA atributos extraídos en capa concatenate')
plt.show()

Ni =4000 # graficar Ni muestras como imagenes en espacio 2D
ind = np.random.randint(0, y.shape[0], Ni)
plot_mnist_2d(zPCA[ind], y[ind], x[ind], img_w = 28, img_h = 28, zoom = 0.5, cmap='binary')
plt.xlabel('componente 1')
plt.ylabel('componente 2')
plt.title('PCA atributos extraídos en capa concatenate')
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['Input']
# Received: inputs=Tensor(shape=(32, 28, 28))
#   warnings.warn(msg)
# 304/313 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# /usr/local/lib/python3.11/dist-packages/keras/src/models/functional.py:237: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: ['Input']
# Received: inputs=Tensor(shape=(None, 28, 28))
#   warnings.warn(msg)
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step
# Text(0.5, 1.0, 'PCA atributos extraídos en capa concatenate')

# %% [markdown]
# ###Punto 2:

# %%
import cupy as cp
from cuml.manifold import UMAP as cuUMAP

# Convertir a cupy para trabajar con cuML
z_A_gpu = cp.asarray(z_A)

# Aplicar UMAP desde RAPIDS (cuML)
umap = cuUMAP(n_components=2, n_neighbors=15, min_dist=0.1, random_state=42)
zUMAP = umap.fit_transform(z_A_gpu)

# Convertir de nuevo a numpy para graficar
zUMAP = zUMAP.get()

# Visualización básica con color por etiqueta
plt.figure(figsize=(10, 6))
plt.scatter(zUMAP[:, 0], zUMAP[:, 1], c=y, cmap='tab10', s=5)
plt.colorbar()
plt.xlabel("UMAP componente 1")
plt.ylabel("UMAP componente 2")
plt.title("UMAP atributos extraídos en capa concatenate")
plt.tight_layout()
plt.show()

# Visualización con imágenes (subset aleatorio)
Ni = 4000
ind = np.random.randint(0, y.shape[0], Ni)
plot_mnist_2d(zUMAP[ind], y[ind], x[ind], img_w=28, img_h=28, zoom=0.5, cmap='binary')
plt.xlabel('UMAP componente 1')
plt.ylabel('UMAP componente 2')
plt.title('UMAP atributos extraídos en capa concatenate')
# Out:
# [2025-06-11 17:09:07.354] [CUML] [info] build_algo set to brute_force_knn because random_state is given
# Text(0.5, 1.0, 'UMAP atributos extraídos en capa concatenate')

# %% [markdown]
# ###Punto 3:

# %%
from sklearn.preprocessing import MinMaxScaler
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

train, test = tf.keras.datasets.mnist.load_data()
images, labels = train

# plt.imshow(images[10000,:,:], cmap = 'binary')
# plt.show()
# print(np.unique(labels))

# Normalización de los valores de los pixeles
images = images / 255.
x, y = test
x = x / 255.
images = np.expand_dims(images, -1)
x = np.expand_dims(x, -1)

images_train, images_valid = images[:-5000], images[-5000:]
labels_train, labels_valid = labels[:-5000], labels[-5000:]
# print(images_train.shape, images_valid.shape, x.shape)

variance = [0.05, 0.25]
inputs_train = [images_train]
inputs_valid = [images_valid]
inputs_test = [x]
for var in variance:
    dim = images_train.shape
    tmp = images_train + (np.sqrt(var)*np.random.randn(images_train.shape[0],dim[1],dim[2],dim[3]))
    tmp = MinMaxScaler().fit_transform(tmp.reshape(dim[0],-1).T).T #fijar señal con ruido de 0 a 1
    inputs_train += [tmp.reshape(dim)]

    dim = images_valid.shape
    tmp = images_valid + (np.sqrt(var)*np.random.randn(images_valid.shape[0],dim[1],dim[2],dim[3]))
    tmp = MinMaxScaler().fit_transform(tmp.reshape(dim[0],-1).T).T
    inputs_valid += [tmp.reshape(dim)]

    dim = x.shape
    tmp = x + (np.sqrt(var)*np.random.randn(x.shape[0],dim[1],dim[2],dim[3]))
    tmp = MinMaxScaler().fit_transform(tmp.reshape(dim[0],-1).T).T
    inputs_test += [tmp.reshape(dim)]

# plt.imshow(np.c_[inputs_valid[0][500,:,:,0],inputs_valid[1][500,:,:,0],inputs_valid[2][500,:,:,0]])
# plt.axis('off')
# plt.colorbar()
# plt.show()

#arquitectura funcional
tf.keras.backend.clear_session()

def sharedLayers(inputLayer):
    x = tf.keras.layers.Conv2D(32, (3,3), activation = 'relu')(inputLayer)
    x = tf.keras.layers.MaxPooling2D((2,2))(x)
    x = tf.keras.layers.Conv2D(64, (3,3), activation = 'relu')(x)
    x = tf.keras.layers.MaxPooling2D((2,2))(x)
    x = tf.keras.layers.Flatten()(x)
    return x

input_l1 = tf.keras.layers.Input(shape = (28, 28, 1), name = 'Clean Input')
input_l2 = tf.keras.layers.Input(shape = (28, 28, 1), name = 'Low Noise Input')
input_l3 = tf.keras.layers.Input(shape = (28, 28, 1), name = 'Noise Input')

# Extracción de características por medio de capas convolucionales
convolutional_layers1 = sharedLayers(input_l1)
convolutional_layers2 = sharedLayers(input_l2)
convolutional_layers3 = sharedLayers(input_l3)

concatenate = tf.keras.layers.concatenate([convolutional_layers1, convolutional_layers2, convolutional_layers3])

# Hacemos converger esas características a una decisión usando capas densas
h1 = tf.keras.layers.Dense(128, activation = 'relu', name = 'h1')(concatenate)
h2 = tf.keras.layers.Dense(64, activation = 'relu', name = 'h2')(h1)

output_lA = tf.keras.layers.Dense(10, activation = "softmax", name = 'Digits')(h2)
output_lB = tf.keras.layers.Dense(2, activation = "softmax", name = 'Parity')(h2)

model = tf.keras.Model(inputs = [input_l1, input_l2, input_l3], outputs = [output_lA, output_lB])
# model.summary()
tf.keras.utils.plot_model(model)

model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = "Adam",
              metrics = ["accuracy","accuracy"])

history = model.fit(
    x = {'Clean Input': inputs_train[0], 'Low Noise Input': inputs_train[1], 'Noise Input': inputs_train[2]},
    y = {'Digits': labels_train, 'Parity': labels_train % 2},
    epochs = 10,
    batch_size = 64,
    validation_data = (
        {'Clean Input': inputs_valid[0], 'Low Noise Input': inputs_valid[1], 'Noise Input': inputs_valid[2]},
        {'Digits': labels_valid, 'Parity': labels_valid % 2}
    )
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Epoch 1/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 21s 15ms/step - Digits_accuracy: 0.8485 - Digits_loss: 0.4958 - Parity_accuracy: 0.9206 - Parity_loss: 0.1822 - loss: 0.6779 - val_Digits_accuracy: 0.9796 - val_Digits_loss: 0.0728 - val_Parity_accuracy: 0.9858 - val_Parity_loss: 0.0416 - val_loss: 0.1157
# Epoch 2/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - Digits_accuracy: 0.9805 - Digits_loss: 0.0633 - Parity_accuracy: 0.9886 - Parity_loss: 0.0318 - loss: 0.0951 - val_Digits_accuracy: 0.9846 - val_Digits_loss: 0.0547 - val_Parity_accuracy: 0.9916 - val_Parity_loss: 0.0261 - val_loss: 0.0816
# Epoch 3/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - Digits_accuracy: 0.9880 - Digits_loss: 0.0377 - Parity_accuracy: 0.9932 - Parity_loss: 0.0195 - loss: 0.0572 - val_Digits_accuracy: 0.9874 - val_Digits_loss: 0.0457 - val_Parity_accuracy: 0.9912 - val_Parity_loss: 0.0260 - val_loss: 0.0725
# Epoch 4/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - Digits_accuracy: 0.9914 - Digits_loss: 0.0277 - Parity_accuracy: 0.9953 - Parity_loss: 0.0132 - loss: 0.0409 - val_Digits_accuracy: 0.9888 - val_Digits_loss: 0.0388 - val_Parity_accuracy: 0.9944 - val_Parity_loss: 0.0184 - val_loss: 0.0579
# Epoch 5/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 5s 6ms/step - Digits_accuracy: 0.9932 - Digits_loss: 0.0209 - Parity_accuracy: 0.9966 - Parity_loss: 0.0094 - loss: 0.0303 - val_Digits_accuracy: 0.9896 - val_Digits_loss: 0.0434 - val_Parity_accuracy: 0.9936 - val_Parity_loss: 0.0229 - val_loss: 0.0670
# Epoch 6/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - Digits_accuracy: 0.9936 - Digits_loss: 0.0194 - Parity_accuracy: 0.9963 - Parity_loss: 0.0107 - loss: 0.0301 - val_Digits_accuracy: 0.9902 - val_Digits_loss: 0.0387 - val_Parity_accuracy: 0.9934 - val_Parity_loss: 0.0229 - val_loss: 0.0622
# Epoch 7/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 6s 7ms/step - Digits_accuracy: 0.9960 - Digits_loss: 0.0122 - Parity_accuracy: 0.9982 - Parity_loss: 0.0052 - loss: 0.0174 - val_Digits_accuracy: 0.9892 - val_Digits_loss: 0.0470 - val_Parity_accuracy: 0.9928 - val_Parity_loss: 0.0260 - val_loss: 0.0736
# Epoch 8/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 10s 7ms/step - Digits_accuracy: 0.9962 - Digits_loss: 0.0111 - Parity_accuracy: 0.9982 - Parity_loss: 0.0055 - loss: 0.0167 - val_Digits_accuracy: 0.9896 - val_Digits_loss: 0.0416 - val_Parity_accuracy: 0.9934 - val_Parity_loss: 0.0229 - val_loss: 0.0652
# Epoch 9/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - Digits_accuracy: 0.9969 - Digits_loss: 0.0093 - Parity_accuracy: 0.9985 - Parity_loss: 0.0040 - loss: 0.0133 - val_Digits_accuracy: 0.9904 - val_Digits_loss: 0.0455 - val_Parity_accuracy: 0.9942 - val_Parity_loss: 0.0231 - val_loss: 0.0694
# Epoch 10/10
# 860/860 ━━━━━━━━━━━━━━━━━━━━ 10s 6ms/step - Digits_accuracy: 0.9971 - Digits_loss: 0.0086 - Parity_accuracy: 0.9984 - Parity_loss: 0.0039 - loss: 0.0125 - val_Digits_accuracy: 0.9904 - val_Digits_loss: 0.0392 - val_Parity_accuracy: 0.9946 - val_Parity_loss: 0.0200 - val_loss: 0.0599

# %%
y_labels = y
y_odd_pair = (y % 2)

z = model.predict(
    {'Clean Input': x, 'Low Noise Input': inputs_test[1], 'Noise Input': inputs_test[2]}
)
accuracy = model.evaluate(
    {'Clean Input': x, 'Low Noise Input': inputs_test[1], 'Noise Input': inputs_test[2]},
    {'Digits': y_labels, 'Parity': y_odd_pair}
)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - Digits_accuracy: 0.9881 - Digits_loss: 0.0449 - Parity_accuracy: 0.9940 - Parity_loss: 0.0217 - loss: 0.0666

# %%
z_digits = z[0]
z_digits.shape
# Out:
# (10000, 10)

# %%
import cupy as cp
from cuml.manifold import UMAP as cuUMAP

# Selección de 4000 muestras aleatorias
n = 4000
ind = np.random.choice(z_digits.shape[0], n, replace=False)
z_n = z_digits[ind, :]
y_n = y[ind]

# Convertir a GPU con cupy
z_n_gpu = cp.asarray(z_n)

# Aplicar UMAP de RAPIDS
umap = cuUMAP(n_components=2, n_neighbors=15, min_dist=0.1, random_state=42)
zUMAP = umap.fit_transform(z_n_gpu)

# Devolver a NumPy para graficar
zUMAP = zUMAP.get()

# Graficar
plt.figure(figsize=(10, 6))
plt.scatter(zUMAP[:, 0], zUMAP[:, 1], c=y_n, cmap='tab10', s=5)
plt.colorbar()
plt.xlabel('UMAP componente 1')
plt.ylabel('UMAP componente 2')
plt.title('UMAP atributos extraídos en salida de dígitos')
plt.tight_layout()
plt.show()
# Out:
# [2025-06-11 17:16:23.052] [CUML] [info] build_algo set to brute_force_knn because random_state is given

# %%
z_parity = z[1]
z_parity.shape
# Out:
# (10000, 2)

# %%
import cupy as cp
from cuml.manifold import UMAP as cuUMAP

# Seleccionar 4000 muestras aleatorias
n = 4000
ind = np.random.choice(z_parity.shape[0], n, replace=False)
z_n = z_parity[ind, :]
y_n = y_odd_pair[ind]

# Convertir a cupy (GPU)
z_n_gpu = cp.asarray(z_n)

# Aplicar UMAP cuML
umap = cuUMAP(n_components=2, n_neighbors=15, min_dist=0.1, random_state=42)
zUMAP = umap.fit_transform(z_n_gpu)

# Volver a NumPy para visualización
zUMAP = zUMAP.get()

# Visualizar
plt.figure(figsize=(10, 6))
plt.scatter(zUMAP[:, 0], zUMAP[:, 1], c=y_n, cmap='coolwarm', s=5)
plt.colorbar()
plt.xlabel('UMAP componente 1')
plt.ylabel('UMAP componente 2')
plt.title('UMAP atributos extraídos en salida de números pares/impares')
plt.tight_layout()
plt.show()
# Out:
# [2025-06-11 17:19:11.924] [CUML] [info] build_algo set to brute_force_knn because random_state is given
